# %%
import warnings
warnings.simplefilter('ignore')

import pandas as pd

df = pd.read_csv('s3://ia340data/cscpopendata.csv') # load the data from s3
df.head() #show the top 5 rows
# Out:
#    CDPHId                                       ProductName  CSFId  CSF  \
# 0       2  ULTRA COLOR RICH EXTRA PLUMP LIPSTICK-ALL SHADES    NaN  NaN
# 1       3                        Glover's Medicated Shampoo    NaN  NaN
# 2       3                        Glover's Medicated Shampoo    NaN  NaN
# 3       4          PRECISION GLIMMER EYE LINER-ALL SHADES �    NaN  NaN
# 4       5       AVON BRILLIANT SHINE LIP GLOSS-ALL SHADES �    NaN  NaN
#
#    CompanyId          CompanyName BrandName  PrimaryCategoryId  \
# 0          4         New Avon LLC      AVON                 44
# 1        338  J. Strickland & Co.  Glover's                 18
# 2        338  J. Strickland & Co.  Glover's                 18
# 3          4         New Avon LLC      AVON                 44
# 4          4         New Avon LLC      AVON                 44
#
#                      PrimaryCategory  SubCategoryId  ...   CasNumber  \
# 0    Makeup Products (non-permanent)             53  ...  13463-67-7
# 1  Hair Care Products (non-coloring)             25  ...  65996-92-1
# 2  Hair Care Products (non-coloring)             25  ...    140-67-0
# 3    Makeup Products (non-permanent)             46  ...  13463-67-7
# 4    Makeup Products (non-permanent)             52  ...  13463-67-7
#
#    ChemicalId            ChemicalName  InitialDateReported  \
# 0           6        Titanium dioxide           06/17/2009
# 1           4  Distillates (coal tar)           07/01/2009
# 2           5               Estragole           07/01/2009
# 3           7        Titanium dioxide           07/09/2009
# 4           8        Titanium dioxide           07/09/2009
#
#   MostRecentDateReported DiscontinuedDate ChemicalCreatedAt ChemicalUpdatedAt  \
# 0             08/28/2013       02/01/2011        07/09/2009        07/09/2009
# 1             07/01/2009              NaN        07/01/2009        07/01/2009
# 2             07/01/2009              NaN        07/02/2009        07/02/2009
# 3             08/28/2013              NaN        07/09/2009        07/09/2009
# 4             08/28/2013       02/01/2011        07/09/2009        07/09/2009
#
#   ChemicalDateRemoved ChemicalCount
# 0                 NaN             1
# 1                 NaN             2
# 2                 NaN             2
# 3                 NaN             1
# 4                 NaN             1
#
# [5 rows x 22 columns]

# %%
df.shape #show the number of rows and columns
# Out:
# (114635, 22)

# %%
df['BrandName'] #select a column
# Out:
# 0              AVON
# 1          Glover's
# 2          Glover's
# 3              AVON
# 4              AVON
#             ...
# 114630       YANBAL
# 114631       YANBAL
# 114632       YANBAL
# 114633       YANBAL
# 114634    Old Spice
# Name: BrandName, Length: 114635, dtype: object

# %%
df.sort_values(by='ChemicalCount') #sort data by a column
# Out:
#        CDPHId                                        ProductName    CSFId  \
# 33278   11224  MC 25.4oz Cucumber Melon Lavender Vanilla Hand...  16180.0
# 21045    5519  White Diamonds Body Radiance Silky Moisturizin...      NaN
# 21044    5518                        Gentle Lotion Skin Cleanser      NaN
# 21043    5517                            Sung Alfred Sung Parfum      NaN
# 28478    8646                          Antibacterial Lotion Soap      NaN
# ...       ...                                                ...      ...
# 60824   22212                               Moisturizing Shampoo      NaN
# 60823   22212                               Moisturizing Shampoo      NaN
# 60822   22212                               Moisturizing Shampoo      NaN
# 60819   22212                               Moisturizing Shampoo      NaN
# 60820   22212                               Moisturizing Shampoo      NaN
#
#             CSF  CompanyId                       CompanyName  \
# 33278  FD&C Dye        485         Olympic Mountain Products
# 21045       NaN         69             Elizabeth Arden, Inc.
# 21044       NaN        218  Kimberly-Clark Global Sales, LLC
# 21043       NaN         69             Elizabeth Arden, Inc.
# 28478       NaN        388                  Prime Source LLC
# ...         ...        ...                               ...
# 60824       NaN        165                 Regis Corporation
# 60823       NaN        165                 Regis Corporation
# 60822       NaN        165                 Regis Corporation
# 60819       NaN        165                 Regis Corporation
# 60820       NaN        165                 Regis Corporation
#
#                BrandName  PrimaryCategoryId  \
# 33278      Morgan Childs                  6
# 21045   Elizabeth Taylor                 90
# 21044    Kimcare General                 90
# 21043        Aflred Sung                 12
# 28478       PRIME SOURCE                 74
# ...                  ...                ...
# 60824  Regis Design Line                 18
# 60823  Regis Design Line                 18
# 60822  Regis Design Line                 18
# 60819  Regis Design Line                 18
# 60820  Regis Design Line                 18
#
#                          PrimaryCategory  SubCategoryId  ...   CasNumber  \
# 33278                      Bath Products            159  ...  68603-42-9
# 21045                Skin Care Products             104  ...  25013-16-5
# 21044                Skin Care Products              93  ...  68603-42-9
# 21043                         Fragrances             14  ...    100-42-5
# 28478             Personal Care Products            170  ...  68603-42-9
# ...                                  ...            ...  ...         ...
# 60824  Hair Care Products (non-coloring)             25  ...     50-00-0
# 60823  Hair Care Products (non-coloring)             25  ...     75-21-8
# 60822  Hair Care Products (non-coloring)             25  ...     79-43-6
# 60819  Hair Care Products (non-coloring)             25  ...    123-91-1
# 60820  Hair Care Products (non-coloring)             25  ...     79-06-1
#
#        ChemicalId              ChemicalName  InitialDateReported  \
# 33278       16499   Cocamide diethanolamine           05/12/2010
# 21045        9395  Butylated hydroxyanisole           10/15/2009
# 21044        9405   Cocamide diethanolamine           10/15/2009
# 21043        9393                   Styrene           10/15/2009
# 28478       13486   Cocamide diethanolamine           12/15/2009
# ...           ...                       ...                  ...
# 60824       33801        Formaldehyde (gas)           02/04/2014
# 60823       33800            Ethylene oxide           02/04/2014
# 60822       33799       Dichloroacetic acid           02/04/2014
# 60819       33796               1,4-Dioxane           02/04/2014
# 60820       33797                Acrylamide           02/04/2014
#
#       MostRecentDateReported DiscontinuedDate ChemicalCreatedAt  \
# 33278             12/29/2016       11/19/2014        05/12/2010
# 21045             01/18/2017       05/02/2016        10/15/2009
# 21044             05/17/2013       10/24/2011        10/15/2009
# 21043             01/19/2017              NaN        10/15/2009
# 28478             06/22/2020              NaN        12/15/2009
# ...                      ...              ...               ...
# 60824             02/04/2014              NaN        02/04/2014
# 60823             02/04/2014              NaN        02/04/2014
# 60822             02/04/2014              NaN        02/04/2014
# 60819             02/04/2014              NaN        02/04/2014
# 60820             02/04/2014              NaN        02/04/2014
#
#       ChemicalUpdatedAt ChemicalDateRemoved ChemicalCount
# 33278        12/29/2016          02/28/2013             0
# 21045        04/15/2010          04/01/2010             0
# 21044        05/17/2013          10/24/2011             0
# 21043        03/14/2011          11/05/2010             0
# 28478        06/22/2020          08/05/2013             0
# ...                 ...                 ...           ...
# 60824        02/04/2014                 NaN             9
# 60823        02/04/2014                 NaN             9
# 60822        02/04/2014                 NaN             9
# 60819        02/04/2014                 NaN             9
# 60820        02/04/2014                 NaN             9
#
# [114635 rows x 22 columns]

# %%
df[0:5] #slice by rows
# Out:
#    CDPHId                                       ProductName  CSFId  CSF  \
# 0       2  ULTRA COLOR RICH EXTRA PLUMP LIPSTICK-ALL SHADES    NaN  NaN
# 1       3                        Glover's Medicated Shampoo    NaN  NaN
# 2       3                        Glover's Medicated Shampoo    NaN  NaN
# 3       4          PRECISION GLIMMER EYE LINER-ALL SHADES �    NaN  NaN
# 4       5       AVON BRILLIANT SHINE LIP GLOSS-ALL SHADES �    NaN  NaN
#
#    CompanyId          CompanyName BrandName  PrimaryCategoryId  \
# 0          4         New Avon LLC      AVON                 44
# 1        338  J. Strickland & Co.  Glover's                 18
# 2        338  J. Strickland & Co.  Glover's                 18
# 3          4         New Avon LLC      AVON                 44
# 4          4         New Avon LLC      AVON                 44
#
#                      PrimaryCategory  SubCategoryId  ...   CasNumber  \
# 0    Makeup Products (non-permanent)             53  ...  13463-67-7
# 1  Hair Care Products (non-coloring)             25  ...  65996-92-1
# 2  Hair Care Products (non-coloring)             25  ...    140-67-0
# 3    Makeup Products (non-permanent)             46  ...  13463-67-7
# 4    Makeup Products (non-permanent)             52  ...  13463-67-7
#
#    ChemicalId            ChemicalName  InitialDateReported  \
# 0           6        Titanium dioxide           06/17/2009
# 1           4  Distillates (coal tar)           07/01/2009
# 2           5               Estragole           07/01/2009
# 3           7        Titanium dioxide           07/09/2009
# 4           8        Titanium dioxide           07/09/2009
#
#   MostRecentDateReported DiscontinuedDate ChemicalCreatedAt ChemicalUpdatedAt  \
# 0             08/28/2013       02/01/2011        07/09/2009        07/09/2009
# 1             07/01/2009              NaN        07/01/2009        07/01/2009
# 2             07/01/2009              NaN        07/02/2009        07/02/2009
# 3             08/28/2013              NaN        07/09/2009        07/09/2009
# 4             08/28/2013       02/01/2011        07/09/2009        07/09/2009
#
#   ChemicalDateRemoved ChemicalCount
# 0                 NaN             1
# 1                 NaN             2
# 2                 NaN             2
# 3                 NaN             1
# 4                 NaN             1
#
# [5 rows x 22 columns]

# %%
df[df['ChemicalCount']>5] # select rows by values
# Out:
#         CDPHId                                        ProductName    CSFId  \
# 15612     3671                                    Hydrate Shampoo      NaN
# 15613     3671                                    Hydrate Shampoo      NaN
# 15614     3671                                    Hydrate Shampoo      NaN
# 15615     3671                                    Hydrate Shampoo      NaN
# 15616     3671                                    Hydrate Shampoo      NaN
# ...        ...                                                ...      ...
# 113912   41308  Self Heating Face Mask With Natural Activated ...  64642.0
# 113913   41308  Self Heating Face Mask With Natural Activated ...  64642.0
# 113914   41308  Self Heating Face Mask With Natural Activated ...  64642.0
# 113915   41308  Self Heating Face Mask With Natural Activated ...  64642.0
# 113916   41308  Self Heating Face Mask With Natural Activated ...  64642.0
#
#               CSF  CompanyId        CompanyName          BrandName  \
# 15612         NaN        165  Regis Corporation  Regis Design Line
# 15613         NaN        165  Regis Corporation  Regis Design Line
# 15614         NaN        165  Regis Corporation  Regis Design Line
# 15615         NaN        165  Regis Corporation  Regis Design Line
# 15616         NaN        165  Regis Corporation  Regis Design Line
# ...           ...        ...                ...                ...
# 113912  Fragrance       1388    Cosmopharm Ltd.           Careline
# 113913  Fragrance       1388    Cosmopharm Ltd.           Careline
# 113914  Fragrance       1388    Cosmopharm Ltd.           Careline
# 113915  Fragrance       1388    Cosmopharm Ltd.           Careline
# 113916  Fragrance       1388    Cosmopharm Ltd.           Careline
#
#         PrimaryCategoryId                    PrimaryCategory  SubCategoryId  \
# 15612                  18  Hair Care Products (non-coloring)             25
# 15613                  18  Hair Care Products (non-coloring)             25
# 15614                  18  Hair Care Products (non-coloring)             25
# 15615                  18  Hair Care Products (non-coloring)             25
# 15616                  18  Hair Care Products (non-coloring)             25
# ...                   ...                                ...            ...
# 113912                 90                Skin Care Products              93
# 113913                 90                Skin Care Products              93
# 113914                 90                Skin Care Products              93
# 113915                 90                Skin Care Products              93
# 113916                 90                Skin Care Products              93
#
#         ... CasNumber  ChemicalId                           ChemicalName  \
# 15612   ...  123-91-1        6479                            1,4-Dioxane
# 15613   ...       NaN        6480  Arsenic (inorganic arsenic compounds)
# 15614   ...   79-43-6        6481                    Dichloroacetic acid
# 15615   ...   75-21-8        6482                         Ethylene oxide
# 15616   ...   50-00-0        6483                     Formaldehyde (gas)
# ...     ...       ...         ...                                    ...
# 113912  ...   94-59-7       67679                                Safrole
# 113913  ...  140-67-0       67680                              Estragole
# 113914  ...   93-15-2       67681                          Methyleugenol
# 113915  ...   93-15-2       67682                          Methyleugenol
# 113916  ...   93-15-2       67683                          Methyleugenol
#
#         InitialDateReported MostRecentDateReported DiscontinuedDate  \
# 15612            10/12/2009             02/06/2014       02/06/2014
# 15613            10/12/2009             02/06/2014       02/06/2014
# 15614            10/12/2009             02/06/2014       02/06/2014
# 15615            10/12/2009             02/06/2014       02/06/2014
# 15616            10/12/2009             02/06/2014       02/06/2014
# ...                     ...                    ...              ...
# 113912           03/20/2020             03/20/2020              NaN
# 113913           03/20/2020             03/20/2020              NaN
# 113914           03/20/2020             03/20/2020              NaN
# 113915           03/20/2020             03/20/2020              NaN
# 113916           03/20/2020             03/20/2020              NaN
#
#        ChemicalCreatedAt ChemicalUpdatedAt ChemicalDateRemoved ChemicalCount
# 15612         10/12/2009        02/06/2014          10/12/2009             7
# 15613         10/12/2009        02/06/2014          10/12/2009             7
# 15614         10/12/2009        02/06/2014          10/12/2009             7
# 15615         10/12/2009        02/06/2014          10/12/2009             7
# 15616         10/12/2009        02/06/2014          10/12/2009             7
# ...                  ...               ...                 ...           ...
# 113912        03/20/2020        03/20/2020                 NaN             6
# 113913        03/20/2020        03/20/2020                 NaN             6
# 113914        03/20/2020        03/20/2020          03/20/2020             6
# 113915        03/20/2020        03/20/2020                 NaN             6
# 113916        03/20/2020        03/20/2020          03/20/2020             6
#
# [119 rows x 22 columns]

# %%
df.info() #show the data types and number of null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114635 entries, 0 to 114634
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   CDPHId                  114635 non-null  int64
#  1   ProductName             114635 non-null  object
#  2   CSFId                   80662 non-null   float64
#  3   CSF                     80237 non-null   object
#  4   CompanyId               114635 non-null  int64
#  5   CompanyName             114635 non-null  object
#  6   BrandName               114408 non-null  object
#  7   PrimaryCategoryId       114635 non-null  int64
#  8   PrimaryCategory         114635 non-null  object
#  9   SubCategoryId           114635 non-null  int64
#  10  SubCategory             114635 non-null  object
#  11  CasId                   114635 non-null  int64
#  12  CasNumber               108159 non-null  object
#  13  ChemicalId              114635 non-null  int64
#  14  ChemicalName            114635 non-null  object
#  15  InitialDateReported     114635 non-null  object
#  16  MostRecentDateReported  114635 non-null  object
#  17  DiscontinuedDate        12920 non-null   object
#  18  ChemicalCreatedAt       114635 non-null  object
#  19  ChemicalUpdatedAt       114635 non-null  object
#  20  ChemicalDateRemoved     2985 non-null    object
#  21  ChemicalCount           114635 non-null  int64
# dtypes: float64(1), int64(7), object(14)
# memory usage: 19.2+ MB

# %%
df.isnull().sum() #show the number of rows containing null value
# Out:
# CDPHId                         0
# ProductName                    0
# CSFId                      33973
# CSF                        34398
# CompanyId                      0
# CompanyName                    0
# BrandName                    227
# PrimaryCategoryId              0
# PrimaryCategory                0
# SubCategoryId                  0
# SubCategory                    0
# CasId                          0
# CasNumber                   6476
# ChemicalId                     0
# ChemicalName                   0
# InitialDateReported            0
# MostRecentDateReported         0
# DiscontinuedDate          101715
# ChemicalCreatedAt              0
# ChemicalUpdatedAt              0
# ChemicalDateRemoved       111650
# ChemicalCount                  0
# dtype: int64

# %%
df = df.dropna() #drop null values
df.isnull().sum()
# Out:
# CDPHId                    0
# ProductName               0
# CSFId                     0
# CSF                       0
# CompanyId                 0
# CompanyName               0
# BrandName                 0
# PrimaryCategoryId         0
# PrimaryCategory           0
# SubCategoryId             0
# SubCategory               0
# CasId                     0
# CasNumber                 0
# ChemicalId                0
# ChemicalName              0
# InitialDateReported       0
# MostRecentDateReported    0
# DiscontinuedDate          0
# ChemicalCreatedAt         0
# ChemicalUpdatedAt         0
# ChemicalDateRemoved       0
# ChemicalCount             0
# dtype: int64

# %%
df.describe() #statistical summary of the data
# Out:
#              CDPHId         CSFId    CompanyId  PrimaryCategoryId  \
# count     95.000000     95.000000    95.000000          95.000000
# mean   11336.252632  25122.421053   440.515789          38.115789
# std     7619.608633  11900.733835   333.723190          23.161259
# min      349.000000   1559.000000    71.000000           6.000000
# 25%     6762.000000  16125.500000   175.000000          18.000000
# 50%     8688.000000  22552.000000   333.000000          44.000000
# 75%    13163.000000  30365.500000   485.000000          44.000000
# max    35984.000000  60105.000000  1279.000000         106.000000
#
#        SubCategoryId        CasId    ChemicalId  ChemicalCount
# count      95.000000    95.000000     95.000000      95.000000
# mean       66.305263   557.221053  18335.715789       0.652632
# std        47.411300   238.874942  13397.840015       0.560555
# min         7.000000   104.000000      0.000000       0.000000
# 25%        42.000000   296.000000  10706.000000       0.000000
# 50%        51.000000   656.000000  13528.000000       1.000000
# 75%        65.000000   656.000000  20560.000000       1.000000
# max       170.000000  1102.000000  61748.000000       2.000000

# %%
df['ChemicalCount'].value_counts() #show the count of unique values
# Out:
# ChemicalCount
# 1    54
# 0    37
# 2     4
# Name: count, dtype: int64

# %%
df = df.rename(columns={"ProductName": "product", "CompanyName": "Company","BrandName":"Brand",}) 
df.head()
# Out:
#       CDPHId             product   CSFId     CSF  CompanyId  \
# 516      349  Body Lotion SPF-25  1559.0  Tinted         71
# 521      349  Body Lotion SPF-25  1559.0  Tinted         71
# 5573    1759         Nail Polish  2579.0    Pink        118
# 5574    1759         Nail Polish  2580.0   Green        118
# 5575    1759         Nail Polish  2581.0  Purple        118
#
#                            Company   Brand  PrimaryCategoryId  \
# 516   Sunrider Manufacturing, L.P.  Oi-Lin                 90
# 521   Sunrider Manufacturing, L.P.  Oi-Lin                106
# 5573              Added Extras LLC   Topps                 59
# 5574              Added Extras LLC   Topps                 59
# 5575              Added Extras LLC   Topps                 59
#
#            PrimaryCategory  SubCategoryId  ...   CasNumber  ChemicalId  \
# 516    Skin Care Products             102  ...  13463-67-7         377
# 521   Sun-Related Products            107  ...  13463-67-7         377
# 5573         Nail Products             65  ...    140-88-5        2021
# 5574         Nail Products             65  ...    140-88-5        2021
# 5575         Nail Products             65  ...    140-88-5        2021
#
#           ChemicalName  InitialDateReported MostRecentDateReported  \
# 516   Titanium dioxide           09/02/2009             09/19/2013
# 521   Titanium dioxide           09/02/2009             09/19/2013
# 5573    Ethyl acrylate           09/29/2009             12/30/2010
# 5574    Ethyl acrylate           09/29/2009             12/30/2010
# 5575    Ethyl acrylate           09/29/2009             12/30/2010
#
#      DiscontinuedDate ChemicalCreatedAt ChemicalUpdatedAt ChemicalDateRemoved  \
# 516        01/01/2010        09/02/2009        09/19/2013          01/01/2010
# 521        01/01/2010        09/02/2009        09/19/2013          01/01/2010
# 5573       01/01/2009        09/29/2009        09/29/2009          01/01/2009
# 5574       01/01/2009        09/29/2009        09/29/2009          01/01/2009
# 5575       01/01/2009        09/29/2009        09/29/2009          01/01/2009
#
#      ChemicalCount
# 516              0
# 521              0
# 5573             0
# 5574             0
# 5575             0
#
# [5 rows x 22 columns]

# %%
df['product'].value_counts() #show the count of unique values
# Out:
# product
# Burt�s Bees Tinted Lip Balm                                                        12
# C.O. Bigelow Mentha Lip Shine                                                      10
# Defining Eyeshadow                                                                  8
# Beyond the Zone Spike It Hair Cement                                                6
# instacolor TEMPORARY HAIR COLOR SPRAY                                               5
# Hamptons Classic Palette - Eye Shadows (Seashell, Pebble, Sand Dune, Driftwood)     4
# Anti-Aging Hydratint Sunscreen SPF 20                                               4
# Bath & Shower Gel                                                                   4
# Nail Polish                                                                         3
# Lip Buff                                                                            2
# Whirlpool Shampoo & Body Wash                                                       2
# LIFE IS SHOWER GEL                                                                  2
# Bar Soap                                                                            2
# Suave Body Wash Ocean Breeze                                                        2
# Body Lotion SPF-25                                                                  2
# STRAWBERRY HAND WASH                                                                1
# SWEET LEMON LIP BUTTER                                                              1
# Blush Tint                                                                          1
# Tangled Web Eye Defining Gel Liner                                                  1
# NOIR G DE GUERLAIN - EXCEPTIONAL COMPLETE MASCARA                                   1
# Beauty Bar Pink                                                                     1
# Pop of Minnie Mini Lipstick Set                                                     1
# Glam Intense Super Long Wear Gel Liner                                              1
# Holiday Glitter Quad - Party UP                                                     1
# Professional System Heat Protect & Shine Spray                                      1
# Silken Earth Body Shimmer                                                           1
# Essenza 25.4oz Hand Soap French Lavender                                            1
# Aromatherapy Sleep Mineral Bath Salts                                               1
# MC 25.4oz Cucumber Melon Lavender Vanilla Hand Soap                                 1
# MC 25.4oz Cucumber Melon Hand Soap                                                  1
# MC Tangerine 17.5oz Hand Soap                                                       1
# Essenza 25.4oz Hand Soap Rosemary Mint                                              1
# Essenza 25.4oz Hand Soap Ginger Citrus                                              1
# You're In Control Lemon Balm Shaping Gel                                            1
# Rise 'n Shine White Willow Volumizing Foam                                          1
# Recovery Complex Replenishing Hair Balm                                             1
# Prime Time Chamomile Styling Foundation                                             1
# Beat the Heat Pomegranate Thermal Protector                                         1
# All Day Straight Safflower Smoothing Gel                                            1
# After Tweeze Cream                                                                  1
# Burt�s Bees Sunscreen SPF 30                                                        1
# Baked Hydrating Powder Foundation                                                   1
# Name: count, dtype: int64

# %%
MostRecentDateReported
# Out:
# Brand
# Burt�s Bees                      13
# Bath & Body Works                11
# TRUETOUCH                         8
# Beyond the Zone                   6
# Bain de Terre                     6
# instacolor                        5
# La Prairie                        4
# Arbonne                           4
# The Body Shop                     4
# Crabtree & Evelyn                 4
# Morgan Childs                     3
# Topps                             3
# Essenza                           3
# Disney                            2
# Oi-Lin                            2
# Central                           2
# Bioelements                       2
# Coast                             2
# Suave                             2
# Aubrey Organics                   1
# No7                               1
# Anastasia Beverly Hills           1
# GUERLAIN                          1
# Dove                              1
# Palladio                          1
# Milk Makeup                       1
# Nature's Gate                     1
# Your Name Professional Brands     1
# Name: count, dtype: int64

# %%
MostRecentDateReported
# Out:
# ChemicalName
# Titanium dioxide                                                                                       61
# Cocamide diethanolamine                                                                                15
# Estragole                                                                                               8
# Benzophenone                                                                                            5
# Ethyl acrylate                                                                                          3
# Retinol/retinyl esters, when in daily dosages in excess of 10,000 IU, or 3,000 retinol equivalents.     1
# Carbon black (airborne, unbound particles of respirable size)                                           1
# Trade Secret                                                                                            1
# Name: count, dtype: int64

# %%
df['Brand'].value_counts() #show the count of unique values
# Out:
# Brand
# Burt�s Bees                      13
# Bath & Body Works                11
# TRUETOUCH                         8
# Beyond the Zone                   6
# Bain de Terre                     6
# instacolor                        5
# La Prairie                        4
# Arbonne                           4
# The Body Shop                     4
# Crabtree & Evelyn                 4
# Morgan Childs                     3
# Topps                             3
# Essenza                           3
# Disney                            2
# Oi-Lin                            2
# Central                           2
# Bioelements                       2
# Coast                             2
# Suave                             2
# Aubrey Organics                   1
# No7                               1
# Anastasia Beverly Hills           1
# GUERLAIN                          1
# Dove                              1
# Palladio                          1
# Milk Makeup                       1
# Nature's Gate                     1
# Your Name Professional Brands     1
# Name: count, dtype: int64

# %%
df.to_csv('clean_data.csv') #store the cleaned data to local compute
